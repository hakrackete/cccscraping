# %%
import time
import requests
from bs4 import BeautifulSoup
from datetime import datetime

URL = "https://tickets.events.ccc.de/39c3/secondhand/"
HEADERS = {
    "User-Agent": "Mozilla/5.0 (ticket-checker; +https://example.com)"
}

# %%
r = requests.get(URL, headers=HEADERS, timeout=10)
r.raise_for_status()

soup = BeautifulSoup(r.text, "html.parser")

# Beispiel: Textsuche (robust, aber simpel)
page_text = soup.get_text().lower()

# %%
text = "no tickets available at the moment. check back later!"

# %%
def check_tickets():
    r = requests.get(URL, headers=HEADERS, timeout=10)
    r.raise_for_status()

    soup = BeautifulSoup(r.text, "html.parser")

    # Beispiel: Textsuche (robust, aber simpel)
    page_text = soup.get_text().lower()

    if text not in page_text:
        print("JETZT")
        timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
        filename = f"responses/secondhand_{timestamp}.html"
        with open(filename, "w",encoding="utf-8") as f:
            f.write(r.text)
        return True
    else:
        print("nicht")
        return False

# %%
while True:
    try:
        available = check_tickets()

        if available:
            print("🎉 TICKETS MÖGLICHERWEISE VERFÜGBAR!")
            # hier könntest du abbrechen oder benachrichtigen
        else:
            print("❌ Keine Tickets verfügbar")

    except Exception as e:
        print("⚠️ Fehler beim Abrufen:", e)

    time.sleep(60)
# Out:
# nicht
# ❌ Keine Tickets verfügbar
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 14
#      11 except Exception as e:
#      12     print("⚠️ Fehler beim Abrufen:", e)
# ---> 14 time.sleep(60)
#
# KeyboardInterrupt:

# %%
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"responses/secondhand_{timestamp}.html"
with open(filename, "w",encoding="utf-8") as f:
    f.write(r.text)

# %%
while True:
    try:
        available = check_tickets()

        if available:
            print("🎉 TICKETS MÖGLICHERWEISE VERFÜGBAR!")
            # hier könntest du abbrechen oder benachrichtigen
        else:
            print("❌ Keine Tickets verfügbar")

    except Exception as e:
        print("⚠️ Fehler beim Abrufen:", e)

    time.sleep(60)

# %%
if text in page_text:
    print("yes")
# Out:
# yes

# %%
import subprocess

# %%
subprocess.Popen([
    "firefox",
    "--new-window",
    "https://tickets.events.ccc.de/39c3/secondhand/"
])
# Out:
# <Popen: returncode: None args: ['firefox', '--new-window', 'https://tickets....>
# Gtk-Message: 10:20:04.212: Not loading module "atk-bridge": The functionality is provided by GTK natively. Please try to not load it.
# Gtk-Message: 10:20:04.259: Failed to load module "canberra-gtk-module"
# Gtk-Message: 10:20:04.260: Failed to load module "canberra-gtk-module"
